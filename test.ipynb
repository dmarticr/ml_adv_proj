# %%
import requests

## Congress
headers = {'X-API-Key': 'Li9aCR2BjLZviTE2vhRXQ9QDqq1XU8NxXUXkQDbA',}
pp_base = 'https://api.propublica.org/congress/v1/'

# GET https://api.propublica.org/congress/v1/{congress}/bills/{bill-id}.json

CONGRESS = 117

bill_id = 'hr3967'

data = requests.get(f'{pp_base}{CONGRESS}/bills/{bill_id}.json', headers = headers).json()
data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2023 Pro Publica Inc. All Rights Reserved.',
#  'results': [{'bill_id': 'hr3967-117',
#    'bill_slug': 'hr3967',
#    'congress': '117',
#    'bill': 'H.R.3967',
#    'bill_type': 'hr',
#    'number': 'H.R.3967',
#    'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr3967.json',
#    'title': 'To improve health care and benefits for veterans exposed to toxic substances, and for other purposes.',
#    'short_title': 'Honoring our PACT Act of 2022',
#    'sponsor_title': '',
#    'sponsor': 'Mark Takano',
#    'sponsor_id': 'T000472',
#    'sponsor_uri': 'https://api.propublica.org/congress/v1/members/T000472.json',
#    'sponsor_party': 'D',
#    'sponsor_state': 'CA',
#    'gpo_pdf_uri': None,
#    'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/3967',
#    'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr3967',
#    'introduced_date': '2021-06-17',
#    'active': True,
#    'last_vote': '2022-06-16',
#    'house_passage': '2022-03-03',
#    'senate_passage': '2022-06-16',
#    'enacted': None,
#    'vetoed': None,
#    'cosponsors': 100,
#    'cosponsors_by_party': {'D': 97, 'R': 3},
#    'withdrawn_cosponsors': 0,
#    'primary_subject': '',
#    'committees': '',
#    'committee_codes': ['HSVR', 'HSAS'],
#    'subcommittee_codes': ['HSVR09'],
#    'latest_major_action_date': '2022-06-16',
#    'latest_major_action': 'Message on Senate action sent to the House.',
#    'house_passage_vote': '2022-03-03',
#    'senate_passage_vote': '2022-06-16',
#    'summary': "Sergeant First Class Heath Robinson Honoring our Promise to Address Comprehensive Toxics Act of 2022 or the Honoring our PACT Act of 2022 This bill addresses health care, presumption of service-connection, research, resources, and other matters related to veterans who were exposed to toxic substances during military service. TITLE I--EXPANSION OF HEALTH CARE ELIGIBILITY Conceding Our Veterans' Exposure Now and Necessitating Training Act of 2022 or the COVENANT Act of 2022 Subtitle A--Toxic-Exposed Veterans (Sec. 103) This section provides eligibility for Department of Veterans Affairs (VA) medical care, including mental health services and counseling, to veterans who (1) participated in a toxic exposure risk activity (e.g., a qualifying activity that requires a corresponding entry in an exposure tracking record system, such as the Individual Longitudinal Exposure Record); (2) served in specified locations on specified dates; or (3) deployed in support of a specified contingency operation. (Sec. 104) The VA must complete an assessment to determine (1) the personnel and material resources necessary to implement the expanded provision of care to the veterans specified in Section 103 of this bill (e.g., veterans who participated in a toxic exposure risk activity), and (2) the total number of veterans who served in specified locations on specified dates and receive hospital care or medical services from the VA, disaggregated by priority group.Subtitle B--Certain Veterans Of Combat Service And Other Matters (Sec. 111) This section extends the eligibility period for VA hospital care, medical services, and nursing home care for combat veterans who served after September 11, 2001, and are toxic-exposed veterans, including those who did not enroll to receive VA care during the eligibility period. TITLE II--TOXIC EXPOSURE PRESUMPTION PROCESS Toxic Exposure in the American Military Act of 2022 or the TEAM Act of 2022 (Sec. 202) This section prescribes the procedures for establishing or removing presumptions of service-connection based on toxic exposure, including by providing for public notice and comment periods and the establishment of a working group to advise and make recommendations regarding toxic exposures during military service. (Sec. 203) The VA must conduct outreach to certain claimants when a law establishes or modifies a presumption of service-connection. Specifically, the VA must identify and conduct outreach for all claims for compensation for a service-connected disability that (1) were submitted to the VA, (2) were evaluated and denied before the new law went into effect, and (3) might have been evaluated differently if the modification had been applicable to the claim. (Sec. 204) The VA must conduct outreach to certain claimants when a law establishes or modifies a presumption of service-connection in relation to dependency and indemnity compensation. Specifically, the VA must identify and conduct outreach for all claims for dependency and indemnity compensation related to service-connected conditions that (1) were submitted to the VA, (2) were evaluated and denied before the new law went into effect, and (3) might have been evaluated differently if the modification had been applicable to the claim. TITLE III--IMPROVING THE ESTABLISHMENT OF SERVICE CONNECTION PROCESS FOR TOXIC-EXPOSED VETERANS Veterans Burn Pits Exposure Recognition Act of 2022 (Sec. 302) This section establishes a presumption that veterans were exposed to certain substances, chemicals, and airborne hazards during military service in specified locations in specified time frames (e.g., on or after August 2, 1990, in Bahrain). (Sec. 303) The VA must provide a veteran with a medical examination regarding the nexus between a disability and toxic exposure risk activity if a veteran submits a disability compensation claim for a service-connected disability with insufficient evidence.  TITLE IV--PRESUMPTIONS OF SERVICE CONNECTION Mark Takai Atomi ...
#    'summary_short': "Sergeant First Class Heath Robinson Honoring our Promise to Address Comprehensive Toxics Act of 2022 or the Honoring our PACT Act of 2022 This bill addresses health care, presumption of service-connection, research, resources, and other matters related to veterans who were exposed to toxic substances during military service. TITLE I--EXPANSION OF HEALTH CARE ELIGIBILITY Conceding Our Veterans' Exposure Now and Necessitating Training Act of 2022 or the COVENANT Act of 2022 Subtitle A--Toxic-Ex...",
#    'cbo_estimate_url': None,
#    'versions': [{'status': 'Engrossed Amendment Senate',
#      'title': 'EAS',
#      'url': 'https://www.govinfo.gov/content/pkg/BILLS-117hr3967eas/xml/BILLS-117hr3967eas.xml',
#      'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/3967/text/eas'},
#     {'status': 'Placed on Calendar Senate',
#      'title': 'PCS',
#      'url': 'https://www.govinfo.gov/content/pkg/BILLS-117hr3967pcs/xml/BILLS-117hr3967pcs.xml',
#      'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/3967/text/pcs'},
#     {'status': 'Engrossed in House',
#      'title': 'EH',
#      'url': 'https://www.govinfo.gov/content/pkg/BILLS-117hr3967eh/xml/BILLS-117hr3967eh.xml',
#      'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/3967/text/eh'},
#     {'status': 'Reported in House',
#      'title': 'RH',
#      'url': 'https://www.govinfo.gov/content/pkg/BILLS-117hr3967rh/xml/BILLS-117hr3967rh.xml',
#      'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/3967/text/rh'},
#     {'status': 'Introduced in House',
#      'title': 'IH',
#      'url': 'https://www.govinfo.gov/content/pkg/BILLS-117hr3967ih/xml/BILLS-117hr3967ih.xml',
#      'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/3967/text/ih'}],
#    'actions': [{'id': 71,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-16',
#      'description': 'Considered by Senate. (consideration: CR S2983-2984, S2988-2991, S2999-3001, S3010-3011)'},
#     {'id': 70,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-16',
#      'description': 'Message on Senate action sent to the House.'},
#     {'id': 69,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-16',
#      'description': 'Passed Senate with an amendment by Yea-Nay Vote. 84 - 14. Record Vote Number: 230.'},
#     {'id': 68,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-16',
#      'description': 'Considered by Senate.'},
#     {'id': 67,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-15',
#      'description': 'Cloture on the measure invoked in Senate by Yea-Nay Vote. 76 - 23. Record Vote Number: 227.'},
#     {'id': 66,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-15',
#      'description': 'Considered by Senate.'},
#     {'id': 65,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-15',
#      'description': 'Cloture on the measure invoked in Senate by Yea-Nay Vote. 76 - 23. Record Vote Number: 227. (CR S2951)'},
#     {'id': 64,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-15',
#      'description': 'Considered by Senate. (consideration: CR S2947-2951, S2954, S2957-2958, S2976-2978)'},
#     {'id': 63,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-14',
#      'description': 'Considered by Senate.'},
#     {'id': 62,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-14',
#      'description': 'Considered by Senate. (consideration: CR S2919-2920, S2926-2927, S2932-2933)'},
#     {'id': 61,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-13',
#      'description': 'Considered by Senate.'},
#     {'id': 60,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-13',
#      'description': 'Considered by Senate. (consideration: CR S2899-2900, S2901-2908)'},
#     {'id': 59,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-09',
#      'description': 'Cloture motion on the measure presented in Senate.'},
#     {'id': 58,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-09',
#      'description': 'Considered by Senate.'},
#     {'id': 57,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-09',
#      'description': 'Considered by Senate. (consideration: CR S2875-2883; S2884-2887)'},
#     {'id': 56,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-09',
#      'description': 'Cloture motion on the measure presented in Senate. (CR S2887)'},
#     {'id': 55,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-09',
#      'description': 'Considered by Senate. (consideration: CR S2875-2883, S2884-2887)'},
#     {'id': 54,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-08',
#      'description': 'Motion to proceed to measure considered in Senate.'},
#     {'id': 53,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-08',
#      'description': 'Motion to proceed to measure considered in Senate. (CR S2843)'},
#     {'id': 52,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-08',
#      'description': 'Measure laid before Senate by motion.'},
#     {'id': 51,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-08',
#      'description': 'Motion to proceed to consideration of measure agreed to in Senate by Voice Vote.'},
#     {'id': 50,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-07',
#      'description': 'Motion to proceed to measure considered in Senate.'},
#     {'id': 49,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-07',
#      'description': 'Cloture on the motion to proceed to the measure invoked in Senate by Yea-Nay Vote. 86 - 12. Record Vote Number: 215.'},
#     {'id': 48,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-07',
#      'description': 'Motion to proceed to measure considered in Senate. (CR S2801)'},
#     {'id': 47,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-06-07',
#      'description': 'Cloture on the motion to proceed to the measure invoked in Senate by Yea-Nay Vote. 86 - 12. Record Vote Number: 215. (CR S2801)'},
#     {'id': 46,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-05-26',
#      'description': 'Motion to proceed to consideration of measure in Senate. (CR S2729)'},
#     {'id': 45,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-05-26',
#      'description': 'Cloture motion on the motion to proceed to the measure presented in Senate.'},
#     {'id': 44,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-05-26',
#      'description': 'Motion to proceed to consideration of measure in Senate.'},
#     {'id': 43,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-05-26',
#      'description': 'Motion to proceed to consideration of measure made in Senate. (CR S2729)'},
#     {'id': 42,
#      'chamber': 'Senate',
#      'action_type': 'Floor',
#      'datetime': '2022-05-26',
#      'description': 'Cloture motion on the motion to proceed to the measure presented in Senate. (CR S2729)'},
#     {'id': 41,
#      'chamber': 'Senate',
#      'action_type': 'Calendars',
#      'datetime': '2022-05-25',
#      'description': 'Read the second time. Placed on Senate Legislative Calendar under General Orders. Calendar No. 388.'},
#     {'id': 40,
#      'chamber': 'Senate',
#      'action_type': 'Calendars',
#      'datetime': '2022-05-24',
#      'description': 'Read the first time. Placed on Senate Legislative Calendar under Read the First Time.'},
#     {'id': 39,
#      'chamber': 'Senate',
#      'action_type': 'IntroReferral',
#      'datetime': '2022-03-03',
#      'description': 'Received in the Senate.'},
#     {'id': 38,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-03',
#      'description': 'Motion to reconsider laid on the table Agreed to without objection.'},
#     {'id': 37,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-03',
#      'description': 'On passage Passed by the Yeas and Nays: 256 - 174 (Roll no. 57).'},
#     {'id': 36,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-03',
#      'description': 'The previous question was ordered pursuant to the rule.'},
#     {'id': 35,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-03',
#      'description': 'POSTPONED PROCEEDINGS - At the conclusion of debate on the Ryan amendment, the Chair put the question on adoption of the amendment and by voice vote, announced that the ayes had prevailed. Mr. Takano demanded the yeas and nays and the Chair postponed further proceedings until a time to be announced.'},
#     {'id': 34,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-03',
#      'description': 'The previous question was ordered on the amendment (A007) pursuant to the rule.'},
#     {'id': 33,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-03',
#      'description': 'DEBATE - Pursuant to the provisions of H. Res. 950, the House proceeded with 10 minutes of debate on the Ryan amendment No. 23.'},
#     {'id': 32,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-03',
#      'description': 'POSTPONED PROCEEDINGS - At the conclusion of debate on the Ruiz amendment, the Chair put the question on adoption of the amendment and by voice vote, announced that the ayes had prevailed. Mr. Takano demanded the yeas and nays and the Chair postponed further proceedings until a time to be announced.'},
#     {'id': 31,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-03',
#      'description': 'DEBATE - Pursuant to the provisions of H. Res. 950, the House proceeded with 10 minutes of debate on the Ruiz amendment No. 22.'},
#     {'id': 30,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-03',
#      'description': 'DEBATE - Pursuant to the provisions of H. Res. 950, the House proceeded with 10 minutes of debate on the Ross amendment No. 20.'},
#     {'id': 29,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-03',
#      'description': 'Considered as unfinished business. (consideration: CR H1279-1284)'},
#     {'id': 28,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-03',
#      'description': 'Pursuant to clause 1(c) of rule XIX, the House resumed consideration of H.R. 3967.'},
#     {'id': 27,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-02',
#      'description': 'Considered as unfinished business.'},
#     {'id': 26,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-02',
#      'description': 'Considered under the provisions of rule H. Res. 950.'},
#     {'id': 25,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-02',
#      'description': 'Pursuant to clause 1(c) of rule XIX, further proceedings on H.R. 3967 were postponed.'},
#     {'id': 24,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-02',
#      'description': 'UNFINISHED BUSINESS - The Chair announced that the unfinished business was on agreeing to amendments, which had been debated earlier and on which further proceedings had been postponed.'},
#     {'id': 23,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-02',
#      'description': 'Pursuant to clause 1(c) of rule XIX, the House resumed consideration of H.R. 3967.'},
#     {'id': 22,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-02',
#      'description': 'POSTPONED PROCEEDINGS - At the conclusion of debate on the Brownley amendment, the Chair put the question on agreeing to the amendment and by voice vote, announced that the ayes had prevailed. Mr. Weber demanded the yeas and nays and the Chair postponed further proceedings until a time to be announced.'},
#     {'id': 21,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-02',
#      'description': 'DEBATE - Pursuant to the provisions of H. Res. 950, the House proceeded with 10 minutes of debate on the Brownley amendment No. 6.'},
#     {'id': 20,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-02',
#      'description': 'POSTPONED PROCEEDINGS - At the conclusion of debate on the Miller-Meeks amendment, the Chair put the question on agreeing to the amendment and by voice vote, announced that the noes had prevailed. Ms. Miller-Meeks demanded the yeas and nays and the Chair postponed further proceedings until a time to be announced.'},
#     {'id': 19,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-02',
#      'description': 'DEBATE - Pursuant to the provisions of H. Res. 950, the House proceeded with 10 minutes of debate on the Miller-Meeks amendment No. 5.'},
#     {'id': 18,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-02',
#      'description': 'POSTPONED PROCEEDINGS - At the conclusion of debate on the Takano amendments en bloc, the Chair put the question on agreeing to the amendments and by voice vote, announced that the ayes had prevailed. Mr. Biggs demanded the yeas and nays and the Chair postponed further proceedings until a time to be announced.'},
#     {'id': 17,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-02',
#      'description': 'DEBATE - Pursuant to the provisions of H. Res. 950, the House proceeded with 20 minutes of debate on the Mr. Takano amendment en bloc.'},
#     {'id': 16,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-02',
#      'description': 'DEBATE - The House continued with further debate on H.R. 3967.'},
#     {'id': 15,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-02',
#      'description': 'DEBATE - The House proceeded with one hour of debate on H.R. 3967.'},
#     {'id': 14,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-02',
#      'description': 'Rule provides for consideration of H.R. 3967 with 1 hour of general debate. Previous question shall be considered as ordered without intervening motions except motion to recommit. Measure will be considered read. Specified amendments are in order. An amendment in the nature of a substitute consisting of the text of Rules Committee Print 117-33, modified by the amendment printed in Part A of the report is considered as adopted.'},
#     {'id': 13,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-02',
#      'description': 'Considered as unfinished business. (consideration: CR H1255-1257)'},
#     {'id': 12,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-02',
#      'description': 'Considered under the provisions of rule H. Res. 950. (consideration: CR H1219-1246)'},
#     {'id': 11,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-03-01',
#      'description': 'Rule H. Res. 950 passed House.'},
#     {'id': 10,
#      'chamber': 'House',
#      'action_type': 'Committee',
#      'datetime': '2022-03-01',
#      'description': "Supplemental report filed by the Committee on Veterans' Affairs, H. Rept. 117-249, Part II."},
#     {'id': 9,
#      'chamber': 'House',
#      'action_type': 'Floor',
#      'datetime': '2022-02-28',
#      'description': 'Rules Committee Resolution H. Res. 950 Reported to House. Rule provides for consideration of H.R. 3967 with 1 hour of general debate. Previous question shall be considered as ordered without intervening motions except motion to recommit. Measure will be considered read. Specified amendments are in order. An amendment in the nature of a substitute consisting of the text of Rules Committee Print 117-33, modified by the amendment printed in Part A of the report is considered as adopted.'},
#     {'id': 8,
#      'chamber': 'House',
#      'action_type': 'Calendars',
#      'datetime': '2022-02-22',
#      'description': 'Placed on the Union Calendar, Calendar No. 179.'},
#     {'id': 7,
#      'chamber': 'House',
#      'action_type': 'Discharge',
#      'datetime': '2022-02-22',
#      'description': 'Committee on Armed Services discharged.'},
#     {'id': 6,
#      'chamber': 'House',
#      'action_type': 'Committee',
#      'datetime': '2022-02-22',
#      'description': "Reported by the Committee on Veterans' Affairs. H. Rept. 117-249, Part I."},
#     {'id': 5,
#      'chamber': 'House',
#      'action_type': 'Committee',
#      'datetime': '2021-06-24',
#      'description': 'Ordered to be Reported by the Yeas and Nays: 14 - 11.'},
#     {'id': 4,
#      'chamber': 'House',
#      'action_type': 'Committee',
#      'datetime': '2021-06-24',
#      'description': 'Committee Consideration and Mark-up Session Held.'},
#     {'id': 3,
#      'chamber': 'House',
#      'action_type': 'Committee',
#      'datetime': '2021-06-24',
#      'description': 'Forwarded by Subcommittee to Full Committee .'},
#     {'id': 2,
#      'chamber': 'House',
#      'action_type': 'Committee',
#      'datetime': '2021-06-22',
#      'description': 'Referred to the Subcommittee on Disability Assistance and Memorial Affairs.'},
#     {'id': 1,
#      'chamber': 'House',
#      'action_type': 'IntroReferral',
#      'datetime': '2021-06-17',
#      'description': "Referred to the Committee on Veterans' Affairs, and in addition to the Committee on Armed Services, for a period to be subsequently determined by the Speaker, in each case for consideration of such provisions as fall within the jurisdiction of the committee concerned."}],
#    'presidential_statements': [{'date': '',
#      'position': '',
#      'url': 'https://www.whitehouse.gov/wp-content/uploads/2022/02/SAP-HR3967.pdf',
#      'veto_threat': '',
#      'would_sign': 'false'},
#     {'date': '',
#      'position': '',
#      'url': 'https://www.whitehouse.gov/wp-content/uploads/2022/06/SAP-HR3967-PACT-Act-Senate.pdf',
#      'veto_threat': '',
#      'would_sign': 'false'}],
#    'votes': [{'chamber': 'House',
#      'date': '2022-03-03',
#      'time': '10:59:00',
#      'roll_call': '57',
#      'question': 'On Passage',
#      'result': 'Passed',
#      'total_yes': 256,
#      'total_no': 174,
#      'total_not_voting': 3,
#      'api_url': 'https://api.propublica.org/congress/v1/117/house/sessions/2/votes/57.json'},
#     {'chamber': 'House',
#      'date': '2022-03-03',
#      'time': '10:33:00',
#      'roll_call': '56',
#      'question': 'On Agreeing to the Amendment',
#      'result': 'Agreed to',
#      'total_yes': 348,
#      'total_no': 78,
#      'total_not_voting': 7,
#      'api_url': 'https://api.propublica.org/congress/v1/117/house/sessions/2/votes/56.json'},
#     {'chamber': 'House',
#      'date': '2022-03-03',
#      'time': '10:14:00',
#      'roll_call': '55',
#      'question': 'On Agreeing to the Amendment',
#      'result': 'Agreed to',
#      'total_yes': 425,
#      'total_no': 0,
#      'total_not_voting': 8,
#      'api_url': 'https://api.propublica.org/congress/v1/117/house/sessions/2/votes/55.json'},
#     {'chamber': 'House',
#      'date': '2022-03-02',
#      'time': '17:00:00',
#      'roll_call': '54',
#      'question': 'On Agreeing to the Amendment',
#      'result': 'Agreed to',
#      'total_yes': 425,
#      'total_no': 0,
#      'total_not_voting': 8,
#      'api_url': 'https://api.propublica.org/congress/v1/117/house/sessions/2/votes/54.json'},
#     {'chamber': 'House',
#      'date': '2022-03-02',
#      'time': '16:43:00',
#      'roll_call': '53',
#      'question': 'On Agreeing to the Amendment',
#      'result': 'Failed',
#      'total_yes': 203,
#      'total_no': 223,
#      'total_not_voting': 7,
#      'api_url': 'https://api.propublica.org/congress/v1/117/house/sessions/2/votes/53.json'},
#     {'chamber': 'House',
#      'date': '2022-03-02',
#      'time': '16:23:00',
#      'roll_call': '52',
#      'question': 'On Agreeing to the Amendment',
#      'result': 'Agreed to',
#      'total_yes': 331,
#      'total_no': 96,
#      'total_not_voting': 6,
#      'api_url': 'https://api.propublica.org/congress/v1/117/house/sessions/2/votes/52.json'},
#     {'chamber': 'Senate',
#      'date': '2022-06-16',
#      'time': '11:34:00',
#      'roll_call': '230',
#      'question': 'On Passage of the Bill',
#      'result': 'Bill Passed',
#      'total_yes': 84,
#      'total_no': 14,
#      'total_not_voting': 2,
#      'api_url': 'https://api.propublica.org/congress/v1/117/senate/sessions/2/votes/230.json'},
#     {'chamber': 'Senate',
#      'date': '2022-06-15',
#      'time': '12:36:00',
#      'roll_call': '227',
#      'question': 'On the Cloture Motion',
#      'result': 'Cloture Motion Agreed to',
#      'total_yes': 76,
#      'total_no': 23,
#      'total_not_voting': 1,
#      'api_url': 'https://api.propublica.org/congress/v1/117/senate/sessions/2/votes/227.json'},
#     {'chamber': 'Senate',
#      'date': '2022-06-15',
#      'time': '11:49:00',
#      'roll_call': '226',
#      'question': 'On the Amendment',
#      'result': 'Amendment Agreed to',
#      'total_yes': 84,
#      'total_no': 15,
#      'total_not_voting': 1,
#      'api_url': 'https://api.propublica.org/congress/v1/117/senate/sessions/2/votes/226.json'},
#     {'chamber': 'Senate',
#      'date': '2022-06-13',
#      'time': '17:29:00',
#      'roll_call': '225',
#      'question': 'On the Cloture Motion',
#      'result': 'Cloture Motion Agreed to',
#      'total_yes': 78,
#      'total_no': 17,
#      'total_not_voting': 5,
#      'api_url': 'https://api.propublica.org/congress/v1/117/senate/sessions/2/votes/225.json'},
#     {'chamber': 'Senate',
#      'date': '2022-06-07',
#      'time': '12:28:00',
#      'roll_call': '215',
#      'question': 'On the Cloture Motion',
#      'result': 'Cloture Motion Agreed to',
#      'total_yes': 86,
#      'total_no': 12,
#      'total_not_voting': 2,
#      'api_url': 'https://api.propublica.org/congress/v1/117/senate/sessions/2/votes/215.json'}]}]}
