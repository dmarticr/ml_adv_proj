# %% [markdown]
# # SVM - Pedro
#
# 25/Abril/2023
# Fuente: https://medium.com/@bedigunjit/simple-guide-to-text-classification-nlp-using-svm-and-naive-bayes-with-python-421db3a72d34

# %%
# Cargar paquetes
import warnings

# Filter out warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score

# %%
# Cargar base de datos
df = pd.read_pickle("data_final.pkl")

# %%
# filter only to house bills and senate bills - Victor
df = df[(df['BillType'] == 'hr') | (df['bill_type'] == 's')]

# %%
# Pass either senate or congress
df['Target'] = np.where((df['PassH']==1) | (df['PassS']==1), 1, 0)

# %%
# Keep only my interest columns
Corpus = df[['summary', 'Target']]
column_name_mapping = {'summary': 'text', 'Target': 'label'}
Corpus.rename(columns=column_name_mapping, inplace=True)

# %%
# Start the pre-processing according to the article - takes around 30min
np.random.seed(500)
# Step - a : Remove blank rows if any.
Corpus['text'].dropna(inplace=True)
# Step - b : Change all the text to lower case. This is required as python interprets 'dog' and 'DOG' differently
Corpus['text'] = [entry.lower() for entry in Corpus['text']]
# Step - c : Tokenization : In this each entry in the corpus will be broken into set of words
Corpus['text']= [word_tokenize(entry) for entry in Corpus['text']]
# Step - d : Remove Stop words, Non-Numeric and perfom Word Stemming/Lemmenting.
# WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV
for index,entry in enumerate(Corpus['text']):
    # Declaring Empty List to store the words that follow the rules for this step
    Final_words = []
    # Initializing WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()
    # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
            Final_words.append(word_Final)
    # The final processed set of words for each iteration will be stored in 'text_final'
    Corpus.loc[index,'text_final'] = str(Final_words)

# %%
import pickle
# Corpus.dropna(subset=['label'], inplace=True)
Corpus.to_pickle("corpus.pkl")

# %%
# Splitting data
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(Corpus['text_final'],Corpus['label'],test_size=0.3)

# %%
# Encoding
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
# Vectorization
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(Corpus['text_final'].values.astype(str))
Train_X_Tfidf = Tfidf_vect.transform(Train_X.values.astype(str))
Test_X_Tfidf = Tfidf_vect.transform(Test_X.values.astype(str))

# %%
print(Tfidf_vect.vocabulary_)
# Out:
# {'withdraws': 4954, 'congress': 926, 'approval': 291, 'north': 3050, 'american': 220, 'free': 1957, 'trade': 4619, 'agreement': 159, 'direct': 1325, 'president': 3480, 'provide': 3595, 'write': 4979, 'notice': 3056, 'withdrawal': 4952, 'government': 2047, 'canada': 597, 'mexico': 2835, 'authorizes': 390, 'secretary': 4092, 'army': 316, 'carry': 630, 'project': 3552, 'hurricane': 2214, 'storm': 4351, 'damage': 1134, 'reduction': 3762, 'west': 4914, 'beach': 446, 'new': 3008, 'river': 3992, 'carolina': 626, 'substantially': 4403, 'accordance': 34, 'plan': 3374, 'describe': 1266, 'report': 3877, 'chief': 704, 'engineer': 1596, 'date': 1140, 'september': 4130, 'periodic': 3324, 'monitoring': 2903, 'economic': 1502, 'life': 2649, 'city': 726, 'coastal': 772, 'december': 1161, 'modifies': 2896, 'improvement': 2283, 'change': 686, 'authorized': 388, 'maintenance': 2725, 'eight': 1527, 'foot': 1909, 'disability': 1333, 'benefit': 466, 'fairness': 1787, 'act': 61, 'amend': 216, 'title': 4591, 'ii': 2241, 'old': 3134, 'age': 147, 'survivor': 4464, 'insurance': 2399, 'oasdi': 3084, 'social': 4234, 'security': 4098, 'ssa': 4300, 'eliminate': 1549, 'waiting': 4879, 'period': 3323, 'individual': 2331, 'include': 2301, 'disabled': 1335, 'widow': 4931, 'widower': 4932, 'eligible': 1548, 'base': 434, 'intervene': 2457, 'reconsideration': 3732, 'review': 3969, 'process': 3525, 'govern': 2044, 'decision': 1165, 'entitlement': 1620, 'bring': 546, 'advancement': 110, 'health': 2132, 'water': 4895, 'resource': 3919, 'development': 1297, 'authorize': 387, 'additional': 80, 'determine': 1289, 'necessary': 2983, 'beyond': 470, 'year': 4988, 'begin': 453, 'initiation': 2357, 'construction': 960, 'current': 1114, 'law': 2591, 'last': 2585, 'estimated': 1662, 'whichever': 4919, 'later': 2587, 'require': 3891, 'end': 1579, 'evaluate': 1672, 'feasibility': 1810, 'continue': 983, 'federal': 1816, 'participation': 3263, 'labor': 2572, 'relation': 3821, 'first': 1869, 'contract': 991, 'negotiation': 2994, 'national': 2960, 'mediation': 2798, 'bind': 485, 'arbitration': 301, 'initial': 2354, 'dispute': 1386, 'revise': 3970, 'certain': 667, 'regulation': 3802, 'occupational': 3104, 'safety': 4026, 'employer': 1569, 'keep': 2541, 'site': 4212, 'log': 2693, 'injury': 2365, 'illness': 2248, 'occur': 3106, 'among': 223, 'employee': 1568, 'particular': 3264, 'whether': 4918, 'employ': 1567, 'directly': 1328, 'contractor': 993, 'temporary': 4528, 'help': 2145, 'leasing': 2607, 'service': 4140, 'chiropractic': 711, 'membership': 2810, 'public': 3610, 'commission': 827, 'corps': 1035, 'make': 2728, 'personnel': 3343, 'appointment': 276, 'united': 4736, 'state': 4324, 'corp': 1032, 'human': 2207, 'hhs': 2152, 'surgeon': 4454, 'general': 2011, 'ensure': 1613, 'doctor': 1425, 'train': 4627, 'equip': 1640, 'otherwise': 3197, 'prepared': 3458, 'fulfill': 1973, 'emergency': 1560, 'response': 3925, 'responsibility': 3926, 'commissioned': 828, 'appoint': 274, 'few': 1833, 'six': 4216, 'regular': 3798, 'ready': 3687, 'reserve': 3902, 'submit': 4388, 'quarterly': 3644, 'relevant': 3825, 'congressional': 927, 'committee': 832, 'measure': 2791, 'take': 4493, 'continuous': 986, 'coverage': 1071, 'xxi': 4987, 'child': 705, 'chip': 710, 'respect': 3920, 'mean': 2787, 'xix': 4983, 'medicaid': 2799, 'case': 633, 'implement': 2265, 'eligibility': 1547, 'option': 3167, 'available': 400, 'target': 4500, 'whose': 4926, 'family': 1791, 'income': 2304, 'poverty': 3428, 'line': 2661, 'discretionary': 1359, 'mandatory': 2738, 'authority': 385, 'specifies': 4280, 'situation': 4214, 'failure': 1784, 'meet': 2806, 'requirement': 3893, 'shall': 4165, 'regard': 3786, 'comply': 877, 'generally': 2012, 'earnings': 1490, 'test': 4545, 'repeal': 3870, 'remove': 3849, 'limitation': 2658, 'amount': 225, 'outside': 3211, 'beneficiary': 465, 'may': 2783, 'earn': 1488, 'without': 4959, 'incur': 2315, 'century': 664, 'civilian': 729, 'conservation': 938, 'order': 3172, 'widespread': 4930, 'unemployment': 472 ...

# %%
# Naive Bayes
Naive = naive_bayes.MultinomialNB()
Naive.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_NB = Naive.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("Naive Bayes Accuracy Score -> ",accuracy_score(predictions_NB, Test_Y)*100)
# Out:
# Naive Bayes Accuracy Score ->  90.86902873259298

# %%
# Vanilla SVM
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)
# Out:
# SVM Accuracy Score ->  90.86902873259298

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
cm = confusion_matrix(Test_Y, predictions_SVM)
ConfusionMatrixDisplay(cm).plot()

# %%
# Ajustando parametros C, el tipo de Kernel y gamma
SVM = svm.SVC(C=1, kernel="poly", degree=3, gamma=10)
SVM.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)
# Out:
# SVM Accuracy Score ->  88.48933544861626

# %%
cm = confusion_matrix(Test_Y, predictions_SVM)
ConfusionMatrixDisplay(cm).plot()

# %%
# Ajustando parametros C, el tipo de Kernel y gamma
SVM = svm.SVC(C=1, kernel='rbf', degree=3, gamma=10)
SVM.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)
# Out:
# SVM Accuracy Score ->  90.00528820729772

# %%
cm = confusion_matrix(Test_Y, predictions_SVM)
ConfusionMatrixDisplay(cm).plot()

# %%
# Ajustando weights
SVM = svm.SVC(C=1, kernel='poly', degree=3, gamma=10, class_weight={0: 1, 1: 4})
SVM.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)
# Out:
# SVM Accuracy Score ->  87.90763264586639

# %%
cm = confusion_matrix(Test_Y, predictions_SVM)
ConfusionMatrixDisplay(cm).plot()

# %%
# Más peso
SVM = svm.SVC(C=1, kernel='poly', degree=3, gamma=10, class_weight={0: 1, 1: 20})
SVM.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)
# Out:
# SVM Accuracy Score ->  75.74475586109642

# %%
cm = confusion_matrix(Test_Y, predictions_SVM)
ConfusionMatrixDisplay(cm).plot()

# %% [markdown]
# ## Oversampling
# Fuente: https://towardsdatascience.com/how-to-balance-a-dataset-in-python-36dff9d12704

# %%
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

over_sampler = RandomOverSampler(random_state=42)
X_res, y_res = over_sampler.fit_resample(Train_X_Tfidf,Train_Y)
print(f"Training target statistics: {Counter(y_res)}")
print(f"Testing target statistics: {Counter(Test_Y)}")
# Out:
# Training target statistics: Counter({0: 12054, 1: 12054})
# Testing target statistics: Counter({0: 5155, 1: 518})

# %%
# Vanilla SVM
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(X_res,y_res)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)

# %%
cm = confusion_matrix(Test_Y, predictions_SVM)
ConfusionMatrixDisplay(cm).plot()

# %%
SVM = svm.SVC(C=1, kernel='poly', degree=3, gamma=10, class_weight={0: 1, 1: 20})
SVM.fit(X_res,y_res)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)
# Out:
# SVM Accuracy Score ->  75.3745813502556

# %%
cm = confusion_matrix(Test_Y, predictions_SVM)
ConfusionMatrixDisplay(cm).plot()
